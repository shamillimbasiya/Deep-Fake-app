# %%
#!pip install coqui-tts
# Out:
# Collecting coqui-tts
#   Using cached coqui_tts-0.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting numpy<2.0,>=1.25.2 (from coqui-tts)
#   Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting cython>=3.0.0 (from coqui-tts)
#   Using cached Cython-3.0.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy>=1.11.2 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts) (1.13.1)
# Requirement already satisfied: torch>=2.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts) (2.5.1)
# Collecting torchaudio>=2.1.0 (from coqui-tts)
#   Using cached torchaudio-2.5.1-cp39-cp39-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: soundfile>=0.12.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts) (0.12.1)
# Collecting librosa>=0.10.1 (from coqui-tts)
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting inflect>=5.6.0 (from coqui-tts)
#   Using cached inflect-7.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm>=4.64.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts) (4.67.0)
# Collecting anyascii>=0.3.0 (from coqui-tts)
#   Using cached anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyyaml>=6.0 (from coqui-tts)
#   Using cached PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: fsspec>=2023.6.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from fsspec[http]>=2023.6.0->coqui-tts) (2024.10.0)
# Requirement already satisfied: packaging>=23.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts) (24.2)
# Collecting pysbd>=0.3.4 (from coqui-tts)
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting matplotlib>=3.7.0 (from coqui-tts)
#   Using cached matplotlib-3.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting coqui-tts-trainer<0.2.0,>=0.1.4 (from coqui-tts)
#   Using cached coqui_tts_trainer-0.1.7-py3-none-any.whl.metadata (8.1 kB)
# Collecting coqpit>=0.0.16 (from coqui-tts)
#   Using cached coqpit-0.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting gruut>=2.4.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut-2.4.0-py3-none-any.whl
# Collecting einops>=0.6.0 (from coqui-tts)
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting transformers>=4.43.0 (from coqui-tts)
#   Using cached transformers-4.46.2-py3-none-any.whl.metadata (44 kB)
# Collecting encodec>=0.1.1 (from coqui-tts)
#   Using cached encodec-0.1.1-py3-none-any.whl
# Collecting num2words>=0.5.11 (from coqui-tts)
#   Using cached num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Collecting spacy<3.8,>=3 (from spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached spacy-3.7.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Requirement already satisfied: psutil>=5 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts) (6.1.0)
# Collecting tensorboard>=2.17.0 (from coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached aiohttp-3.11.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting Babel<3.0.0,>=2.8.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting dateparser~=1.1.1 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached dateparser-1.1.8-py2.py3-none-any.whl.metadata (27 kB)
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut_ipa-0.13.0-py3-none-any.whl
# Collecting gruut-lang-en~=2.0.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut_lang_en-2.0.1-py3-none-any.whl
# Collecting jsonlines~=1.2.0 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached jsonlines-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: networkx>=2.5.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (3.2.1)
# Collecting python-crfsuite~=0.9.7 (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached python_crfsuite-0.9.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting gruut-lang-fr~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut_lang_fr-2.0.2-py3-none-any.whl
# Collecting gruut-lang-de~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut_lang_de-2.0.1-py3-none-any.whl
# Collecting gruut-lang-es~=2.0.0 (from gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached gruut_lang_es-2.0.1-py3-none-any.whl
# Collecting more-itertools>=8.5.0 (from inflect>=5.6.0->coqui-tts)
#   Using cached more_itertools-10.5.0-py3-none-any.whl.metadata (36 kB)
# Collecting typeguard>=4.0.1 (from inflect>=5.6.0->coqui-tts)
#   Using cached typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: audioread>=2.1.9 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from librosa>=0.10.1->coqui-tts) (1.1.0)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached fonttools-4.55.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: pillow>=8 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from matplotlib>=3.7.0->coqui-tts) (11.0.0)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from matplotlib>=3.7.0->coqui-tts) (2.9.0)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.7.0->coqui-tts)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting docopt>=0.6.2 (from num2words>=0.5.11->coqui-tts)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from soundfile>=0.12.0->coqui-tts) (1.17.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached thinc-8.2.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached typer-0.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (2.32.3)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: jinja2 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (3.1.4)
# Requirement already satisfied: setuptools in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (75.1.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached SudachiPy-0.6.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting sudachidict-core>=20211220 (from spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached SudachiDict_core-20241021-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (3.16.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from torch>=2.1->coqui-tts) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from sympy==1.13.1->torch>=2.1->coqui-tts) (1.3.0)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers>=4.43.0->coqui-tts)
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.43.0->coqui-tts)
#   Using cached regex-2024.11.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.43.0->coqui-tts)
#   Using cached safetensors-0.4.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.43.0->coqui-tts)
#   Using cached tokenizers-0.20.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached frozenlist-1.5.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached multidict-6.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached propcache-0.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached yarl-1.17.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (64 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts)
#   Using cached async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pycparser in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts) (2.22)
# Collecting pytz (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzlocal (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts)
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.7.0->coqui-tts) (3.21.0)
# Requirement already satisfied: six in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from jsonlines~=1.2.0->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts) (1.16.0)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts) (4.3.6)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached pydantic_core-2.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa>=0.10.1->coqui-tts) (3.5.0)
# Collecting absl-py>=0.4 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached grpcio-1.67.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.17.0->coqui-tts-trainer<0.2.0,>=0.1.4->coqui-tts)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from typeguard>=4.0.1->inflect>=5.6.0->coqui-tts) (8.5.0)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached cloudpathlib-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached smart_open-7.0.5-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from jinja2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (3.0.2)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached marisa_trie-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/eliho/miniconda3/envs/wav2lip/lib/python3.9/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached coqui_tts-0.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Using cached anyascii-0.3.2-py3-none-any.whl (289 kB)
# Using cached coqpit-0.0.17-py3-none-any.whl (13 kB)
# Using cached coqui_tts_trainer-0.1.7-py3-none-any.whl (56 kB)
# Using cached Cython-3.0.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached einops-0.8.0-py3-none-any.whl (43 kB)
# Using cached inflect-7.4.0-py3-none-any.whl (34 kB)
# Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Using cached matplotlib-3.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Using cached num2words-0.5.13-py3-none-any.whl (143 kB)
# Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Using cached PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (737 kB)
# Using cached spacy-3.7.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
# Using cached torchaudio-2.5.1-cp39-cp39-manylinux1_x86_64.whl (3.4 MB)
# Using cached transformers-4.46.2-py3-none-any.whl (10.0 MB)
# Using cached aiohttp-3.11.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached contourpy-1.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (321 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
# Using cached dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
# Using cached fonttools-4.55.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Using cached kiwisolver-1.4.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached langcodes-3.4.1-py3-none-any.whl (182 kB)
# Using cached more_itertools-10.5.0-py3-none-any.whl (60 kB)
# Using cached murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Using cached preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Using cached python_crfsuite-0.9.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached regex-2024.11.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (780 kB)
# Using cached safetensors-0.4.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (436 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
# Using cached SudachiDict_core-20241021-py3-none-any.whl (72.1 MB)
# Using cached SudachiPy-0.6.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Using cached thinc-8.2.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (937 kB)
# Using cached tokenizers-0.20.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached typeguard-4.4.1-py3-none-any.whl (35 kB)
# Using cached typer-0.13.0-py3-none-any.whl (44 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached frozenlist-1.5.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (242 kB)
# Using cached grpcio-1.67.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached multidict-6.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Using cached propcache-0.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
# Using cached protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached smart_open-7.0.5-py3-none-any.whl (61 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached yarl-1.17.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzlocal-5.2-py3-none-any.whl (17 kB)
# Using cached marisa_trie-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: sudachipy, pytz, gruut-lang-fr, gruut-lang-es, gruut-lang-en, gruut-lang-de, docopt, cymem, wrapt, werkzeug, wasabi, tzlocal, tensorboard-data-server, sudachidict-core, spacy-loggers, spacy-legacy, shellingham, safetensors, regex, pyyaml, python-crfsuite, pysbd, pyparsing, pydantic-core, protobuf, propcache, numpy, num2words, murmurhash, multidict, more-itertools, mdurl, marisa-trie, kiwisolver, jsonlines, importlib-resources, gruut-ipa, grpcio, frozenlist, fonttools, einops, cython, cycler, coqpit, cloudpathlib, click, catalogue, Babel, attrs, async-timeout, anyascii, annotated-types, aiohappyeyeballs, absl-py, yarl, typeguard, srsly, smart-open, pydantic, preshed, markdown-it-py, markdown, language-data, huggingface-hub, dateparser, contourpy, blis, aiosignal, tokenizers, tensorboard, rich, matplotlib, langcodes, inflect, gruut, confection, aiohttp, typer, transformers, torchaudio, thinc, librosa, coqui-tts-trainer, weasel, encodec, spacy, coqui-tts
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.9.1
#     Uninstalling librosa-0.9.1:
#       Successfully uninstalled librosa-0.9.1
# Successfully installed Babel-2.16.0 absl-py-2.1.0 aiohappyeyeballs-2.4.3 aiohttp-3.11.2 aiosignal-1.3.1 annotated-types-0.7.0 anyascii-0.3.2 async-timeout-5.0.1 attrs-24.2.0 blis-0.7.11 catalogue-2.0.10 click-8.1.7 cloudpathlib-0.20.0 confection-0.1.5 contourpy-1.3.0 coqpit-0.0.17 coqui-tts-0.24.3 coqui-tts-trainer-0.1.7 cycler-0.12.1 cymem-2.0.8 cython-3.0.11 dateparser-1.1.8 docopt-0.6.2 einops-0.8.0 encodec-0.1.1 fonttools-4.55.0 frozenlist-1.5.0 grpcio-1.67.1 gruut-2.4.0 gruut-ipa-0.13.0 gruut-lang-de-2.0.1 gruut-lang-en-2.0.1 gruut-lang-es-2.0.1 gruut-lang-fr-2.0.2 huggingface-hub-0.26.2 importlib-resources-6.4.5 inflect-7.4.0 jsonlines-1.2.0 kiwisolver-1.4.7 langcodes-3.4.1 language-data-1.2.0 librosa-0.10.2.post1 marisa-trie-1.2.1 markdown-3.7 markdown-it-py-3.0.0 matplotlib-3.9.2 mdurl-0.1.2 more-itertools-10.5.0 multidict-6.1.0 murmurhash-1.0.10 num2words-0.5.13 numpy-1.26.4 preshed-3.0.9 propcache-0.2.0 protobuf-5.28.3 pydantic-2.9.2 pydantic-core-2.23.4 pyparsing-3.2.0 pysbd-0.3.4 python-crfsuite-0.9.11 pytz-2024.2 pyyaml-6.0.2 regex-2024.11.6 rich-13.9.4 safetensors-0.4.5 shellingham-1.5.4 smart-open-7.0.5 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 sudachidict-core-20241021 sudachipy-0.6.8 tensorboard-2.18.0 tensorboard-data-server-0.7.2 thinc-8.2.5 tokenizers-0.20.3 torchaudio-2.5.1 transformers-4.46.2 typeguard-4.4.1 typer-0.13.0 tzlocal-5.2 wasabi-1.1.3 weasel-0.4.1 werkzeug-3.1.3 wrapt-1.16.0 yarl-1.17.1

# %%
from TTS.tts.configs.xtts_config import XttsConfig
from TTS.tts.models.xtts import Xtts

from IPython.display import Audio
from scipy.io.wavfile import write

# %%
from TTS.api import TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)

# %%
tts.tts_to_file(text="It took me quite a long time to develop a voice, and now that I have it I'm not going to be silent.",
                file_path="output.wav",
                speaker_wav="reference_voices/goggins.m4a",
                language="en")
# Out:
# 'output.wav'

# %%
tts.tts_to_file(text="I killed them, I killed them all, every single one of them, they're dead. And not just the men, but the women and children too",
                file_path="output.wav",
                speaker_wav="trump.wav",
                language="en")
# Out:
# 'output.wav'
